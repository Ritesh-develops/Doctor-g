# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritesh-develops/Doctor-g/blob/main/Doctor_g.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
if "COLAB_GPU" in os.environ:
  print("GPU is available")
else:
  print("GPU is disabled")

# %%
# %pwd

# %%
# %pip install ultralytics

# %%
import ultralytics
ultralytics.checks()

# %% [markdown]
# # Import Dataset from Roboflow

# %%
# %pwd

# %%
path="/content/drive/MyDrive/Doctor-g"

# %%
os.chdir(path)
# %pwd

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="M1iydHaHXnMTCiR7blKo")
project = rf.workspace("test-kkdyt").project("x-ray-6foaf")
version = project.version(6)
dataset = version.download("yolov11")

# %% [markdown]
# # Training the Yolov11 over x-ray dataset

# %%
os.chdir("/content/drive/MyDrive/Doctor-g/x-ray-6")
# %pwd

# %%
# !yolo task=detect mode=train model=yolo11s.pt data=data.yaml epochs=100 imgsz=640 batch=16
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # testing the model

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Doctor-g/x-ray-6'

# %%
# !mkdir test_images

# %%
# !ls
# Out:
# data.yaml	    README.roboflow.txt  test_images  valid	  yolo11s.pt
# README.dataset.txt  runs		 train	      yolo11n.pt

# %%
os.chdir("/content/drive/MyDrive/Doctor-g/x-ray-6/test_images")
# %pwd
# Out:
# '/content/drive/MyDrive/Doctor-g/x-ray-6/test_images'

# %%
weights="/content/drive/MyDrive/Doctor-g/x-ray-6/runs/detect/train2/weights"
# !yolo task=detect mode=predict model={weights}/best.pt conf=0.25 source="/content/00001336_000.png"
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,418,218 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1 /content/00001336_000.png: 640x640 1 Aortic enlargement, 1 Cardiomegaly, 15.7ms
# Speed: 3.5ms preprocess, 15.7ms inference, 155.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
